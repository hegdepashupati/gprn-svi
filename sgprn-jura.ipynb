# %% [markdown]
# ## Stochastic Vairationl Inference for Sparse GPRN

# %% [markdown]
# This notebook illustrates implementation of Sparse GPRN with SVI inference for Jura dataset. Swiss Jura dataset consists for geo-spatial measurements of metals Ni Cd and Zn in the Swiss region of Jura. This can be modeled using mutli-response regression methods.
#
# The dataset can be found here :https://sites.google.com/site/goovaertspierre/pierregoovaertswebsite/download/jura-data

# %% [markdown]
# ** Module and data imports **

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import os
import logging
import time
import sys
from scipy.cluster.vq import kmeans
import pickle
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.gridspec as gridspec
from numpy.random import RandomState
rng = RandomState(1231)
# %matplotlib inline

float_type = tf.float64
jitter_level = 1e-5
tf.logging.set_verbosity(tf.logging.WARN)

modelPath = "models/sgprn.ckpt" # model chekpoint path

# %%
from onofftf.main import Param, DataSet, GaussKL, KernSE, GPConditional
from onofftf.utils import modelmanager
from gpflow import transforms

from onofftf.sgprn import build_prior_kl,build_predict,variational_expectations,ell_gamma_pior,generate_train_op
from onofftf.sgprn import plot_sgprn_fit,plot_sgprn_augmentation

# %%
# define trian and test splits
traindf = pd.read_csv("data/train.csv")
testdf  = pd.read_csv("data/test.csv")

Xtrain = traindf[['x', 'y']].as_matrix()
Ytrain = traindf[['cd','ni','zn']].as_matrix()

Xtest = testdf[['x', 'y']].as_matrix()
Ytest = testdf[['cd','ni','zn']].as_matrix()

# %%
train_data = DataSet(Xtrain,Ytrain)

# %% [markdown]
# **Modeling parameter specification**

# %%
###############################################
num_iter      = 50000           # optimization iterations
num_minibatch = 220             # mini-batch size
num_output    = Ytrain.shape[1] # number of responses
num_latent    = 2               # number of latent functions 
num_data      = Xtrain.shape[0] # number of observations 



num_inducing_f = [10            # number of inducing points for latent function \f
                  for i in range(num_latent)]

num_inducing_w = [[10           # number of inducing points for weight matrix components W
                   for i in range(num_output)]
                   for j in range(num_latent)]

num_inducing_g = [[10           # number of inducing points for sparsity function \g
                   for i in range(num_output)]
                   for j in range(num_latent)]


qf_diag = True # diagnoal assumption for inducing posterior S_f
qw_diag = True # diagnoal assumption for inducing posterior S_w
qg_diag = True # diagnoal assumption for inducing posterior S_g

kern_param_learning_rate = 1e-3  # learning rate for kernel parameters
indp_param_learning_rate = 1e-3  # learning rate for inducing parameters
noise_param_learning_rate = 1e-3 # learning rate for noise variance

prior_alpha = 3.  # piror for ell_g ~ Ga(alpha,beta)
prior_beta  = 1.  

###############################################

# %% [markdown]
# ** Parameter initialization**

# %%
init_x = lambda num_init: kmeans(Xtrain,num_init)[0]

# initalize noise variance
init_noisevar = [0.01, 0.01,0.01]


# initialize f's
init_fkvar = np.ones((num_latent,1))*1.5
init_fkell = np.ones((num_latent,1))*1.5

init_Zf = [init_x(i)
           for i in num_inducing_f]

init_u_fm = [np.random.randn(num_inducing_f[i]).reshape(-1,1)*1e-2
             for i in range(num_latent)]
if qf_diag:
    init_u_fs_sqrt = [np.ones(num_inducing_f[i]).reshape(1,-1).T
                      for i in range(num_latent)]
else:
    init_u_fs_sqrt = [np.eye(num_inducing_f[i])
                      for i in range(num_latent)]

# initalize W's
init_wkvar = np.ones((num_latent,num_output))*1.5
init_wkell = np.ones((num_latent,num_output))*1.5

init_Zw = [[init_x(num_inducing_w[j][i])
            for i in range(num_output)]
            for j in range(num_latent)]

init_u_wm = [[np.random.randn(num_inducing_w[j][i]).reshape(-1,1)*1e-2
              for i in range(num_output)]
              for j in range(num_latent)]
if qw_diag:
    init_u_ws_sqrt = [[np.ones(num_inducing_w[j][i]).reshape(1,-1).T
                       for i in range(num_output)]
                       for j in range(num_latent)]
else:
    init_u_ws_sqrt = [[np.eye(num_inducing_w[j][i])
                       for i in range(num_output)]
                       for j in range(num_latent)]
    
# initalize gammas
init_gkvar = np.ones((num_latent,num_output))*10.
init_gkell = np.ones((num_latent,num_output))*2.

init_Zg = [[init_x(num_inducing_g[j][i])
            for i in range(num_output)]
            for j in range(num_latent)]

init_u_gm = [[np.random.randn(num_inducing_g[j][i]).reshape(-1,1)*1e-2
              for i in range(num_output)]
              for j in range(num_latent)]
if qg_diag:
    init_u_gs_sqrt = [[np.ones(num_inducing_g[j][i]).reshape(1,-1).T
                       for i in range(num_output)]
                       for j in range(num_latent)]
else:
    init_u_gs_sqrt = [[np.eye(num_inducing_g[j][i])
                       for i in range(num_output)]
                       for j in range(num_latent)]

# %% [markdown]
# ** Define parameters in TensorFlow **

# %%
# data placeholders
X = tf.placeholder(dtype = float_type)
Y = tf.placeholder(dtype = float_type)


# kernel for latent functions : K_f
with tf.name_scope("f_kern"):
    fkell = [Param(init_fkell[i],transform=transforms.Log1pe(),
                   name="lengthscale_"+str(i),learning_rate = kern_param_learning_rate,summ=False)
             for i in range(num_latent)]

    fkvar = [Param(init_fkvar[i],transform=transforms.Log1pe(),
                   name="variance_"+str(i),learning_rate = kern_param_learning_rate,summ=False)
             for i in range(num_latent)]

fkern_list = [KernSE(fkell[i],fkvar[i])
              for i in range(num_latent)]


# kernel for weight matrix functions : K_w
with tf.name_scope("w_kern"):
    wkell = [[Param(init_wkell[j][i],transform=transforms.Log1pe(),
                   name="lengthscale_"+str(j)+"_"+str(i),learning_rate = kern_param_learning_rate,summ=False)
             for i in range(num_output)]
             for j in range(num_latent)]

    wkvar = [[Param(init_wkvar[j][i],transform=transforms.Log1pe(),
                   name="variance_"+str(j)+"_"+str(i),learning_rate = kern_param_learning_rate,summ=False)
             for i in range(num_output)]
             for j in range(num_latent)]

wkern_list = [[KernSE(wkell[j][i],wkvar[j][i])
             for i in range(num_output)]
             for j in range(num_latent)]


# kernel for sparsity functions : K_g
with tf.name_scope("g_kern"):
    gkell = [[Param(init_gkell[j][i],transform=transforms.Log1pe(),
                   name="lengthscale_"+str(j)+"_"+str(i),learning_rate = kern_param_learning_rate,summ=False)
             for i in range(num_output)]
             for j in range(num_latent)]

    gkvar = [[Param(init_gkvar[j][i],transform=transforms.Log1pe(),
                   name="variance_"+str(j)+"_"+str(i),learning_rate = kern_param_learning_rate,summ=False)
             for i in range(num_output)]
             for j in range(num_latent)]

gkern_list = [[KernSE(gkell[j][i],gkvar[j][i])
             for i in range(num_output)]
             for j in range(num_latent)]


# noise variance parameters
with tf.name_scope("likelihood"):
    noisevar_list = [Param(init_noisevar[i],transform=transforms.Log1pe(),
                     name="variance"+str(i),learning_rate = noise_param_learning_rate,summ=False)
                for i in range(num_output)]

    
# inducing f
with tf.name_scope("f_ind"):
    Zf_list = [Param(init_Zf[i],name="z_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
               for i in range(num_latent)]
        
    u_fm_list = [Param(init_u_fm[i],name="value_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                 for i in range(num_latent)]
    
    if qf_diag:
        u_fs_sqrt_list = [Param(init_u_fs_sqrt[i],transforms.positive,
                                name="variance_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                          for i in range(num_latent)]
    else:
        u_fs_sqrt_list = [Param(init_u_fs_sqrt[i],transforms.LowerTriangular(init_u_fs_sqrt[i].shape[0]),
                                name="variance_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                          for i in range(num_latent)]

# inducing W
with tf.name_scope("w_ind"):
    Zw_list = [[Param(init_Zw[j][i],name="z_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                for i in range(num_output)]
                for j in range(num_latent)]
    
    u_wm_list = [[Param(init_u_wm[j][i],name="value_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                 for i in range(num_output)]
                 for j in range(num_latent)]    
    
    if qw_diag:
        u_ws_sqrt_list = [[Param(init_u_ws_sqrt[j][i],transforms.positive,
                                name="variance_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                          for i in range(num_output)]
                          for j in range(num_latent)]
    else:
        u_ws_sqrt_list = [[Param(init_u_ws_sqrt[j][i],transforms.LowerTriangular(init_u_ws_sqrt[j][i].shape[0]),
                                name="variance_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                          for i in range(num_output)]
                          for j in range(num_latent)]

# inducin g 
# NOTE: locations are shared between \u_W and \u_g
with tf.name_scope("g_ind"):
    u_gm_list = [[Param(init_u_gm[j][i],name="value_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                 for i in range(num_output)]
                 for j in range(num_latent)]    
    
    if qg_diag:
        u_gs_sqrt_list = [[Param(init_u_gs_sqrt[j][i],transforms.positive,
                                name="variance_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                          for i in range(num_output)]
                          for j in range(num_latent)]
    else:
        u_gs_sqrt_list = [[Param(init_u_gs_sqrt[j][i],transforms.LowerTriangular(init_u_ws_sqrt[j][i].shape[0]),
                                name="variance_"+str(j)+"_"+str(i),learning_rate = indp_param_learning_rate,summ=False)
                          for i in range(num_output)]
                          for j in range(num_latent)]

# %% [markdown]
# ** Build lowerbound**

# %%
# build prior
with tf.name_scope("kl"):
    kl = build_prior_kl(u_fm_list,u_fs_sqrt_list,fkern_list,Zf_list,
                        u_wm_list,u_ws_sqrt_list,wkern_list,Zw_list,
                        u_gm_list,u_gs_sqrt_list,gkern_list,Zw_list)
    tf.summary.scalar('kl', kl)

# build predict function
with tf.name_scope("model_build"):
    wfmean, fmean, fvar, wmean, wvar, pgmean, pgvar, wgmean = build_predict(X,u_fm_list,u_fs_sqrt_list,fkern_list,Zf_list,
                                                                      u_wm_list,u_ws_sqrt_list,wkern_list,Zw_list,
                                                                      u_gm_list,u_gs_sqrt_list,gkern_list,Zw_list)

# compute likelihood
with tf.name_scope("var_exp"):
    var_exp = variational_expectations(Y, wfmean, fmean, fvar, wmean, wvar,pgmean,pgvar, noisevar_list)

    # mini-batch scaling
    scale =  tf.cast(num_data, float_type) / tf.cast(num_minibatch, float_type)
    var_exp_scaled = var_exp * scale

# compute prior
with tf.name_scope("prior"):
    cost_prior = tf.reduce_sum(tf.add_n(([[ell_gamma_pior(gkell[j][i].get_tfv(),prior_alpha,prior_beta)
            for i in range(num_output)]
            for j in range(num_latent)])))

# final lower bound
with tf.name_scope("cost"):
    cost =  -(var_exp_scaled - kl + cost_prior)

# %% [markdown]
# ** Run model optimization op **

# %%
train_op = generate_train_op(cost)

sess = tf.InteractiveSession()
saver = tf.train.Saver()

sess.run(tf.global_variables_initializer())

# %%
print('{:>16s}'.format("iteration"),'{:>16s}'.format("objective"),'{:>16s}'.format("var_exp"),'{:>16s}'.format("kl"),'{:>16s}'.format("prior"))

for i in np.arange(1,num_iter+1):
    batch = train_data.next_batch(num_minibatch)
    try:    
        sess.run([train_op],feed_dict={X : batch[0],Y : batch[1]})
        
        if i % 2000 == 0:
            _cost    = cost.eval({X : batch[0],Y : batch[1]})
            _var_exp = var_exp.eval({X : batch[0],Y :batch[1]})
            _kl      = kl.eval({X : batch[0],Y : batch[1]})
            _prior   = cost_prior.eval()
            print('{:>16d}'.format(i),'{:>16.3f}'.format(_cost),'{:>16.3f}'.format(_var_exp),'{:>16.3f}'.format(_kl),'{:>16.3f}'.format(_prior))
       
    except KeyboardInterrupt as e:
        print("Stopping training")
        break
        
modelmngr = modelmanager(saver, sess, modelPath)
modelmngr.save()
# modelmngr.load()
# Out:
#        iteration        objective          var_exp               kl            prior
#             2000      4521791.089     -3824886.552        18848.328           -8.138
#             4000      2039224.580     -1705947.087        30851.431           -8.170
#             6000       867179.713      -715391.183        24960.941           -8.243
#             8000       440091.707      -358937.545        17515.931           -8.394
#            10000       224676.351      -180676.810        11962.040           -8.429
#            12000       124153.526       -98479.664         8207.685           -8.418
#            14000        65673.745       -50911.693         5728.421           -8.377
#            16000        39744.530       -30246.423         4127.878           -8.363
#            18000        28965.180       -21894.432         3180.794           -8.668
#            20000        20888.775       -15572.140         2547.016           -9.104
#            22000        17645.626       -13192.821         2104.795           -9.283
#            24000        13203.948        -9705.048         1769.110           -9.350
#            26000        10725.155        -7810.962         1520.124           -9.398
#            28000         9733.613        -7112.682         1350.598           -9.448
#            30000         8114.031        -5845.122         1223.279           -9.449
#            32000         7558.382        -5461.845         1118.865           -9.436
#            34000         7067.720        -5119.519         1031.228           -9.423
#            36000         6163.531        -4416.911          954.147           -9.475
#            38000         6220.280        -4517.281          892.739           -9.468
#            40000         5471.418        -3929.705          835.630           -9.454
#            42000         5666.062        -4132.617          791.403           -9.443
#            44000         5255.681        -3819.449          749.717           -9.431
#            46000         5178.473        -3784.710          713.415           -9.422
#            48000         4736.404        -3440.553          676.544           -9.391
#            50000         4660.645        -3404.403          643.401           -9.334
# model saved in : models/sgprn.ckpt

# %% [markdown]
# ** Grid plot of the model fit **

# %%
# create grid co-ordinates
x1min = 0.5;x1max = 6.0;x2min =0.5;x2max = 6.0;
xplot, yplot = np.meshgrid(np.linspace(x1min,x1max,30),np.linspace(x2min,x2max,30))
Xplot = np.concatenate([xplot.reshape(-1,1),yplot.reshape(-1,1)],axis=1)

# predictions
pred_plt_wfmean = wfmean.eval({X:Xplot})
pred_plt_fmean = fmean.eval({X:Xplot})
pred_plt_wgmean = wgmean.eval({X:Xplot})

# inducing locations and values
ind_plot_f = [Zf_list[i].get_tfv().eval() 
              for i in range(num_latent)]
ind_plot_w = [[Zw_list[j][i].get_tfv().eval()
              for i in range(num_output)]
              for j in range(num_latent)]

# plot model fit
plot_sgprn_fit(Xtrain,Ytrain,xplot,yplot,
               pred_plt_wfmean,pred_plt_fmean,pred_plt_wgmean,
               ind_plot_f,ind_plot_w)
# Out:
# /mnt/Documents/05CondaEnv/tf13/lib/python3.5/site-packages/matplotlib/gridspec.py:285: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ** Grid plot of sparse matrix augmentation **

# %%
# predictions
pred_plt_wmean = wmean.eval({X:Xplot})
pred_plt_pgmean = pgmean.eval({X:Xplot})

    
plot_sgprn_augmentation(xplot,yplot,pred_plt_wmean,pred_plt_pgmean,ind_plot_w,ind_plot_w)
# Out:
# /mnt/Documents/05CondaEnv/tf13/lib/python3.5/site-packages/matplotlib/gridspec.py:285: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ** Train set predictions **

# %%
mpl.rcParams['figure.figsize'] = (12,6)
fig, ax = plt.subplots(2,3,sharex='all', sharey='all')

pred_trn_wfmean = wfmean.eval({X:Xtrain})

names = ["Cd","Ni","Zn"]
for i in range(3):
    cx1 = ax[0,i].scatter(Xtrain[:,0],Xtrain[:,1],c=Ytrain[:,i])
    cbar1 = fig.colorbar(cx1,ax=ax[0,i],fraction=0.046, pad=0.04)
    ax[0,i].set_title(names[i]+"\n"+"actual")
    ax[0,i].xaxis.set_ticks([])
    ax[0,i].yaxis.set_ticks([])

    cx2 = ax[1,i].scatter(Xtrain[:,0],Xtrain[:,1],c=pred_trn_wfmean[:,i])
    cbar2 = fig.colorbar(cx2,ax=ax[1,i],fraction=0.046, pad=0.04)
    ax[1,i].set_title("predicted ("+r"$\sigma_y$:"+str(np.round(noisevar_list[i].get_tfv().eval(),3))+")")
    ax[1,i].xaxis.set_ticks([])
    ax[1,i].yaxis.set_ticks([])

fig.tight_layout()
plt.show()

# %%
print("train mse:",np.sqrt(np.mean((pred_trn_wfmean - Ytrain)**2,axis=0)))
print("train mae:",np.mean(np.abs(pred_trn_wfmean - Ytrain),axis=0))
# Out:
# train mse: [  0.79370459   5.33002011  19.16934738]
# train mae: [  0.56683328   4.1011803   14.20633736]
